# %%
import pandas as pd
import json
import urllib.request
import numpy as np
data = pd.read_csv('train.csv')
data.head()
import requests

# %%
data['text'] = data['text'].str.replace(pat=r'[A-Za-z0-9]+',repl=r"", regex=True)
data['text'].replace('', np.nan, inplace=True)

# %%
data['text'] = data['text'].str.replace(pat=r'[^\w]', repl=r' ', regex=True)
data['text'].replace('',np.nan, inplace=True)
data['text'] = data['text'].str.replace(',', "")
data['text'] = data['text'].str.replace('.', "")
data['text'] = data['text'].str.replace('(', "")
data['text'] = data['text'].str.replace(')', "")
data['text'] = data['text'].str.replace('=', "")
data['text'] = data['text'].str.replace('[', "")
data['text'] = data['text'].str.replace(']', "")
data['text'] = data['text'].str.replace('-', "")
data['text'] = data['text'].str.replace('_', "")
data['text'] = data['text'].str.replace('\'', "")
data['text'] = data['text'].str.replace('\"', "")
data['text'] = data['text'].str.replace('?', "")
data['text'] = data['text'].str.replace('!', "")
data['text'] = data['text'].str.replace('/', "")
data['text'] = data['text'].str.replace('\\', "")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24148\3445343971.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['text'] = data['text'].str.replace('.', "")
# C:\Users\User\AppData\Local\Temp\ipykernel_24148\3445343971.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['text'] = data['text'].str.replace('(', "")
# C:\Users\User\AppData\Local\Temp\ipykernel_24148\3445343971.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['text'] = data['text'].str.replace(')', "")
# ...

# %%
data['text'] = data['text'].fillna(0)

# %%
for i in range(len(data['text'])):
    if len(data['text'][i]) < 15:
        print(data['text'][i])
# Out:
# 가치제안을 위한 필요사항
# 특강은 녹화본 올라올까요
# 제출은 어떤 걸 하나요
# 번 문제입니다
# 채팅이 비활성화입니다
# 가 접속이 이상합니다
# 미팅 참여 불가합니다
# 원격 부탁드립니다
# 지원부탁드립니다
#  초기 비밀번호가 뭔가요
#  왜 난 걸까요
#  변경이 안된것 같아요ㅠㅠ
# 가 정확히 뭘까요
#  파일 이 안 열립니다
# 계속 이런 오류가 뜹니다
# 동영상 다운로드가 안됩니다
# 스케일링이 되지 않습니다
#     입니다
# 는 무슨뜻의 함수인가요
# 제출 오류가 뜹니다
# 원격지원 요청드립니다
# 가 뭔지 잘모르겠어요
#  제출시 오류가납니다
#  파일이 없다고 나옵니다
# 그냥 열 삭제해도 되나요
# 에러로 첨부하겠습니다
# 빅프로젝트 별도제출
# 교안을 받고싶어요
#  파일 올려졌나요

# %%
import pandas as pd
import requests
data = pd.read_csv('train.csv')
data.head()
# Out:
#                                                 text label
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1  현재 이미지를 여러개 업로드 하기 위해 자바스크립트로 동적으로 폼 여러개 생성하는데...     웹
# 2  glob.glob(PATH) 를 사용할 때 질문입니다.\n\nPATH에 [ ] 가 ...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
import pandas as pd
data = pd.read_csv('test.csv')
data.head()
# Out:
#    id                                               text
# 0   0  팀즈는 노트북으로 접속하고 강의는 데스크톱 이용하려고 하는데 문제는 없을까요?  이...
# 1   1  셀프테스트에서 받은 점수가 해당 교육을 이수하고, 취업 연계등을 하는데 있어서 영향...
# 2   2  a= int(input('정수 A의 값을 입력하시오.:'))\nb= int(inpu...
# 3   3  def max4(a,b,c,d):\n    maximum = a\n    if b&...
# 4   4              i**=2 가  i **=2 와 왜 같은지가 이해가 잘 안됩니다!!

# %%
    
for i in range(len(data)):    
        
    
    client_id = "" # <-- client_id 기입
    client_secret = "" # <-- client_secret 기입
            
        
    a = {'text' : data['text'][i],
            'source' : 'ko',
            'target': 'en'}

    url = "https://naveropenapi.apigw.ntruss.com/nmt/v1/translation"

    header = {"X-NCP-APIGW-API-KEY-ID":client_id,
                    "X-NCP-APIGW-API-KEY":client_secret}

    response = requests.post(url, headers=header, data=a)
    rescode = response.status_code

    if(rescode==200):
        send_data = response.json()
        trans_data = (send_data['message']['result']['translatedText'])
        data['text'][i] = trans_data
    else:
        print("Error Code:" , rescode)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14600\4059008989.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['text'][i] = trans_data

# %%
data.head(50)
# Out:
#     id                                               text
# 0    0  팀즈는 노트북으로 접속하고 강의는 데스크톱 이용하려고 하는데 문제는 없을까요?  이...
# 1    1  셀프테스트에서 받은 점수가 해당 교육을 이수하고, 취업 연계등을 하는데 있어서 영향...
# 2    2  a= int(input('정수 A의 값을 입력하시오.:'))\nb= int(inpu...
# 3    3  def max4(a,b,c,d):\n    maximum = a\n    if b&...
# 4    4              i**=2 가  i **=2 와 왜 같은지가 이해가 잘 안됩니다!!
# 5    5  print('a부터 b까지의 정수의 합을 구합니다.')\na = int(input(...
# 6    6  print('a부터 b까지 정수의 합을 구합니다.')\na = int(input('...
# 7    7  def electricPay(a) : \n    if a =100 and a  20...
# 8    8  def electricPay(kWh):\n    pay = 0\n    if kWh...
# 9    9  for i in range(11) : \n    if i &lt; 7 : \n   ...
# 10  10  n = int(input('정수를 입력하세요 :'))\n\nfor i in rang...
# 11  11  안녕하세요! 항상 친절하게 답변해주셔서 정말 감사드립니다.\n강사님 설명봤는데 이해...
# 12  12  1)split 메소드 결과 값에서 공백을 없애려면 ',   ' 이나 '/   ' 처...
# 13  13                 ... 아무소리도 안들려서 테스트를 못했습니다 불이익 있을까요
# 14  14  안녕하세요!\n복습중에 궁금증이 생겨서 질문드립니다!\n\n1. s4 = "아니면 ...
# ...

# %%
data.shape, a.shape
# Out:
# ((929, 2), (929, 2))

# %%
a = data.copy()

# %%
b = pd.read_csv('english_all.csv')
b.head()
# Out:
#                                                 text label
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1  Currently, I dynamically create multiple forms...     웹
# 2  Question when using glob.glob(PATH).\n\nI'm as...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
a.head(50)
# Out:
#     id                                               text
# 0    0  I'm trying to access Timz with a laptop and us...
# 1    1  Is the score received in the self-test a facto...
# 2    2  Enter a = int ('input') value of integer A.:')...
# 3    3  def max4(a,b,c,d):\n    maximum = a\n    if b&...
# 4    4  I don't understand why i**=2 is the same as i*...
# 5    5  print('a to b) Find the sum of integers.')\nTy...
# 6    6  print('a to b) Find the sum of integers.')\nTy...
# 7    7  def electricPay(a) : \n    if a =100 and a  20...
# 8    8  def electricPay(kWh):\n    pay = 0\n    if kWh...
# 9    9  for i in range(11) : \n    if i &lt; 7 : \n   ...
# 10  10  n = int ('enter an integer :')\n\nfor i in ran...
# 11  11  Hello! Thank you so much for always responding...
# 12  12  1)If you want to remove a space from the split...
# 13  13  ... I couldn't do the test because I couldn't ...
# 14  14  Hello!\nI have a question during the review!\n...
# ...

# %%
a.to_csv('english_test.csv', index=False)

# %%
data.to_csv('english_all.csv', index=False)

# %%
data.shape
# Out:
# (3706, 2)

# %%
print(len(lst))
# Out:
# 3690

# %%
data.head()
# Out:
#                                                 text label
# 0  I wonder if the kernel size here is just decla...   코드2
# 1  Currently, I dynamically create multiple forms...     웹
# 2  It's a question when you use    I'm asking you...   코드2
# 3                    What should I do with the error   코드2
# 4  I understood that this would save images in th...   코드2

# %%
data.to_csv('./english.csv', index=False)

# %%
import requests

def get_translate():
    
    lst = []
    for i in range(len(data['text'])):
        client_id = "" # <-- 돈이 들어서 비공개 처리하였습니다.client_id 기입
        client_secret = "" # <-- 돈이 들어서 비공개 처리하였습니다.client_secret 기입
        
    
        a = {'text' : data['text'][i],
                'source' : 'ko',
                'target': 'en'}

        url = "https://openapi.naver.com/v1/papago/n2mt"

        header = {"X-Naver-Client-Id":client_id,
                "X-Naver-Client-Secret":client_secret}

        response = requests.post(url, headers=header, data=a)
        rescode = response.status_code

        if(rescode==200):
            send_data = response.json()
            trans_data = (send_data['message']['result']['translatedText'])
            lst.append(trans_data)
        else:
            print("Error Code:" , rescode)
    return lst

# %%
pd.read_csv('./english.csv')
# Out:
#                                                    text   label
# 0     I wonder if the kernel size here is just decla...     코드2
# 1     Currently, I dynamically create multiple forms...       웹
# 2     It's a question when you use    I'm asking you...     코드2
# 3                       What should I do with the error     코드2
# 4     I understood that this would save images in th...     코드2
# ...                                                 ...     ...
# 3701  After tokenization, we separated and vectorize...     코드2
# 3702  Is it the highest point among the uploaded val...  시스템 운영
# 3703  The reason for learning Lang in class is to un...      이론
# 3704  The value does not change even if I do it, and...      원격
# 3705  The correlation doesn't come out that big, but...      이론
#
# [3706 rows x 2 columns]

# %%
data = pd.read_csv('./train.csv')
data.head()
# Out:
#                                                 text label
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1  현재 이미지를 여러개 업로드 하기 위해 자바스크립트로 동적으로 폼 여러개 생성하는데...     웹
# 2  glob.glob(PATH) 를 사용할 때 질문입니다.\n\nPATH에 [ ] 가 ...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
data['text'] = data['text'].str.replace(pat=r'[ㄱ-ㅣ가-힣]+',repl=r"", regex=True)
data['text'].replace('', np.nan, inplace=True)

# %%
data.head()
# Out:
#                                                 text label
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1                               ...     ..       .       웹
# 2  glob.glob(PATH)    .\n\nPATH [ ]         .\n\n...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
data['temp'] = " "

# %%
data2 = pd.read_csv('./english.csv')
print(data2['text'][0])
print(data2['text'][1])
# Out:
# I wonder if the kernel size here is just declared on the assumption that the maximum length of a word does not exceed
# Currently, I dynamically create multiple forms in JavaScript to upload multiple images, but I can't create them even if I click them. I can't do anything because it's blocked. Just in case, I can't simply use the basic example code  What's the reason

# %%
data['text'] = data['text'] + data['temp'] + data2['text']

# %%
data.head()
# Out:
#                                                 text label temp
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1               ...     ..       .   Currently, I...     웹
# 2  glob.glob(PATH)    .\n\nPATH [ ]         .\n\n...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
import re
re.sub(r'[.\\/,^%*!\n]', '', data['text'][0])
# Out:
# 'selfconvs1 = nnModuleList([nnConv2d(1 Co (K 100)) for K in Ks])1   K100      100    100    I wonder if the kernel size here is just declared on the assumption that the maximum length of a word does not exceed'

# %%
data.head()
# Out:
#                                                 text label temp
# 0  self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, ...   코드2
# 1               ...     ..       .   Currently, I...     웹
# 2  glob.glob(PATH)    .\n\nPATH [ ]         .\n\n...   코드2
# 3  tmpp = tmp.groupby(by = 'Addr1', as_index=Fals...   코드2
# 4  filename = TEST_IMAGE + str(round(frame_sec)) ...   코드2

# %%
data2.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
data.drop('temp', axis=1, inplace=True)

# %%
data.to_csv('./code+english_translate.csv', index=False)

# %%
data['text'][3]
# Out:
# "tmpp = tmp.groupby(by = 'Addr1', as_index=False)[['Category']].sum()\n\n\nplt.figure(figsize=(15, 5))\nplt.bar(tmpp['Addr1'], tmpp['Category']/1000)\nplt.ticklabel_format(axis='y', style='plain')\nplt.show()\n\n\n : unsupported operand type(s) for /: 'str' and 'int'\n\n  ?!!!! What should I do with the error"

# %%
k = pd.read_csv('./train.csv')
k['text'][3]
# Out:
# "tmpp = tmp.groupby(by = 'Addr1', as_index=False)[['Category']].sum()\n\n\nplt.figure(figsize=(15, 5))\nplt.bar(tmpp['Addr1'], tmpp['Category']/1000)\nplt.ticklabel_format(axis='y', style='plain')\nplt.show()\n\n\n오류 : unsupported operand type(s) for /: 'str' and 'int'\n\n어떻게 해결하면 좋을까요?!!!!"
